# %% [markdown]
# Directions:
# 1. NO INTERNET. If I see any browsers/chats/etc you will get a 0 on the exam.
# 2. You can use your notes.
# 3. You have 90 minutes to do the exam.
# 4. When you're finished, submit the exam to github classroom, double check with me that it is a submitted.

# %% [markdown]
# ## Question 1
#
# 1. Fix the problem with the code below this cell. You want to have a new list of stock prices where each price is multiplied by 5:
#
# 2. Document the code (write what each line of code is doing).
#
# 3. Improve the code. The above code can be written more efficiently - figure out a solution that will use less lines of code.
#
# Bonus: Show that your improved code is faster.

# %%
stock_names = ["AAPL", "MSFT", "GOOGL", "AMZN", "TSLA","NVDA", "META", "BRK.B", "JPM", "JNJ", "V", "PG", "UNH", "HD", "MA", "DIS", "ADBE", "NFLX", "KO", "PEP"]

stock_prices = [185.32, 410.15, 142.87, 178.42, 242.76, 905.21, 492.33, 412.88, 198.44, 156.72, 273.65, 168.91, 521.08, 356.19, 468.27, 109.53, 589.46, 612.84, 60.27, 172.35]

for p in stock_names: 
    length_held = stock_prices*5
    new_list.append(p) 
new_list

# %% [markdown]
# ## Question 2
#
# Using a **for loop**, write code that will analyze the returns of a retirement stock portolio.
#
# The annual returns starting in year 1 are:
#
# [16.39%, 23.31%, 24.23%, -19.44%, 26.89%, 16.26%, 28.88%, -6.24%, 19.42%, 9.54%, -0.73%]
#
# For the first 5 years, the client will invest $3000 a year and the following 5 years they will invest 10000 per year.
# Be sure your code can:
#
#     a. Calculate their investment balance at the end of each year
#
#     b. Calculate the total investment at the end of the 10 year period.
#
#
# Bonus: Add inflationment adjustment.
# Inflation rates starting at year 1:
#
# [0.1, 1.3, 2.1, 2.4, 1.8, 1.2, 4.7, 8, 4.1, 2.9, 2.6]

# %% [markdown]
# ## Question 3
#
# 1. Import the dataset ticketmaster.csv
#
# 2. Use the appropriate package to find the:
#
#     a. average minimum price and average maximum price.
#
#     b. the price of the quantile for the top 25% of maximum price and the standard deviation for maximum price in 2022.
#
#     c. the average ranking for Hip-Hop?
#
#     d. the average ranking for Pop?
#
# 4. Create a new column that includes a binary variable if an Artist was in the top 25% of macimum price for 2022.
