# %% [markdown]
# ### Weekly Task 3 - Roller Coaster Loops
# ![wooo!](https://media.giphy.com/media/SNrC0OKr4YP2U/giphy.gif?cid=ecf05e47lnb8o893cghul7mragm4n7ric88y6ka94wp4r25f&rid=giphy.gif&ct=g)

# %% [markdown]
# Remember the rules of ~Fight~ Code Club:
# 1. ALWAYS DOCUMENT
# 2. Cite resources that you use (paste links)
# 3. Include the names people who you worked with
# 4. Be neat and organized

# %% [markdown]
# ### 1.  Write a for loop that loops through your list of countries and does the following operations:
# #### 1. If that country starts with the letter c, it prints the name of that country
# #### 2. otherwise it adds 1 to a variable called "count"

# %% [markdown]
# ### 2. Write a while loop that calculates celsius to farenheit from 0 up to and including 38 celsius (hint: (32°F − 32) × 5/9 = 0°C)

# %% [markdown]
# ### 3a. Add a line in the code that calculates the total amount of interest charged throughout the loan period AND
#
# ### 3b. Document what each line of code is doing

# %%
# Loan parameters
loan_amount = 50000
interest_rate = 6.35
monthly_payment = 400
loan_term_years = 30

monthly_interest_rate = interest_rate / 100 / 12
balance = loan_amount
month = 0

while balance > 0:
    interest_charge = balance * monthly_interest_rate
    principal_payment = monthly_payment - interest_charge
    balance -= principal_payment
    if month % 12 == 0:
        print(f'balance at month {month}: {balance}')
    month += 1
# Out:
# balance at month 0: 49864.583333333336
# balance at month 12: 48182.59113582082
# balance at month 24: 46390.62843032843
# balance at month 36: 44481.50522355939
# balance at month 48: 42447.561432512346
# balance at month 60: 40280.63614949717
# balance at month 72: 37972.03489766359
# balance at month 84: 35512.49474565998
# balance at month 96: 32892.14714145014
# balance at month 108: 30100.47831616392
# balance at month 120: 27126.287099107798
# balance at month 132: 23957.639974674315
# balance at month 144: 20581.82320082258
# balance at month 156: 16985.291797012116
# balance at month 168: 13153.61519691149
# balance at month 180: 9071.419347820998
# balance at month 192: 4722.325024491621
# balance at month 204: 88.88210983332897
